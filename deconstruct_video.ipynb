# %% [markdown]
# The Google drive directory is mounted using the folder icon on the left side.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The working directory is changed

# %%
import os
dirpath = os.getcwd()
print("current directory is : " + dirpath)
foldername = os.path.basename(dirpath)
print("Directory name is : " + foldername)
os.chdir("/content/drive/MyDrive/Estructura_del_PC/conversiones/video")
dirpath = os.getcwd()
print("current directory is : " + dirpath)
foldername = os.path.basename(dirpath)
print("Directory name is : " + foldername)
# Out:
# current directory is : /content
# Directory name is : content
# current directory is : /content/drive/MyDrive/Estructura_del_PC/conversiones/video
# Directory name is : video

# %%
#@title Form { vertical-output: true }
#@markdown Here is the name of the video.
video_name = "Rick-Cortado.mp4" #@param {type:"string"}
#@markdown You also have to change the name of the video in the audio extract command Below..

# %%
# https://stackoverflow.com/questions/33311153/python-extracting-and-saving-video-frames
import cv2
vidcap = cv2.VideoCapture(f'{video_name}')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  print('Read a new frame: ', success)
  count += 1
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# https://stackoverflow.com/questions/26741116/python-extract-wav-from-video-file
# !ffmpeg -i Rick-Cortado.mp4 -ab 160k -ac 2 -ar 8000 -vn audio_sourc.wav
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
from scipy.io import wavfile
sample_rate, data_audio = wavfile.read('audio_sourc.wav')

# %%
import matplotlib.pyplot as plt
print(data_audio.shape)
h1 =plt.plot(data_audio[:,0])
#h2 = plt.plot(data_audio[:,1])
# Out:
# (27307, 2)

# %%
import numpy as np
print(sample_rate)
print(np.max(data_audio[:,0]))
print(np.min(data_audio[:,0]))
# Out:
# 8000
# 19859
# -18283
